# %% [markdown]
# # __Sensorer og Instrumentering Eksamenstrening__

# %% [markdown]
# ## __Øving 1__

# %% [markdown]
# ### __Oppgave 1__
#
# I kalde vinterstider er det godt å holde varmen i huset. Samtidig er det viktig å passe på at man ikke bruker unødvendig mye strøm på oppvarmingen, og da er det er lurt å holde styr på hvor varmt det egentlig er rundtom i rommet. For å gjøre det, har vi laget et målesystem som måler temperaturen i et gitt rom på samme sted, en gang hvert tiende minutt. Oppvarmingssystemet er laget slik at temperaturen i rommet burde holdes på 20 grader. Temperaturmålingene for de første 20 målingene er:
#
# $T_{målt,1}$ = 20.6, 20.4, 20.4, 20.6, 20.4, 20.8, 20.5, 20.5, 20.5, 20.4, 20.5, 20.5, 20.5, 20.5, 20.4, 20.4, 20.4, 20.5, 20.3, 20.6

# %% [markdown]
# __(a)__ Gi et estimat for standardavviket for disse målingene

# %%
import numpy as np

def approx_mean(array):
    return np.sum(array) / len(array)


def approx_standard_deviation(array):
    return np.sqrt(np.sum((array - approx_mean(array))**2) / (len(array) - 1))

print(f"standardavvik for målingene: {approx_standard_deviation(np.array(T_målt))}")


def approx_standard_deviation(array):
    return (np.sum(array - approx_mean(array))**2) / (len(array) - 1)

T_målt = [20.6, 20.4, 20.4, 20.6, 20.4, 20.8, 20.5, 20.5, 20.5, 20.4, 20.5, 20.5, 20.5, 20.5, 20.4, 20.4, 20.4, 20.5, 20.3, 20.6]
# Out:
# standardavvik for målingene: 0.10894228312566123
